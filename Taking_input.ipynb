# %%
name = input("What your name? ")

print(name)
# Out:
# Dip

# %%
age = input("Age ?")

print(age , type(age))
# Out:
#  <class 'str'>

# %%
age = input("Age ?")

age = int(age)

print(age , type(age))
# Out:
# 23 <class 'int'>

# %%
height = input("Height ?")

print(height , type(height))
# Out:
# 5.6 <class 'str'>

# %%
height = float(input("Height ?"))

print(height , type(height))
# Out:
# 5.6 <class 'float'>
