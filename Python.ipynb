# %%
## if statement
age = 20

if age >= 18:
    print("Hello")
# Out:
# Hello

# %%
## for loop

for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
str="Dip Bhattacharjee"

for i in str :
    print(i)
# Out:
# D
# i
# p
#
# B
# h
# a
# t
# t
# a
# c
# h
# a
# r
# j
# e
# e

# %%
name=["dip","hwllo","hi"]
print(name)
# Out:
# ['dip', 'hwllo', 'hi']

# %%
### ACCESSING LIST ELEMENTS
fruits=["apple","banana","cherry","kiwi","gauva"]

# %%
#fruits[1]
fruits[1:3]
# Out:
# ['banana', 'cherry']

# %%
fruits.append("orange")

# %%
fruits.insert(1,"banana")

# %%
print(fruits)
# Out:
# ['apple', 'banana', 'Watermalon', 'Watermalon', 'Watermalon', 'banana', 'cherry', 'kiwi', 'gauva', 'orange']

# %%
fruits.remove("Watermalon")
print(fruits)
# Out:
# ['apple', 'Watermalon', 'banana', 'cherry', 'kiwi', 'gauva', 'orange']
