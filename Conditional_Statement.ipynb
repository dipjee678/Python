# %%
raining = True

if raining == True:
    print("Rain coat is necessary")
    print("Caution")
else:
    print("Go without rain coat")
    print("This is a sunny day")
# Out:
# Rain coat is necessary
# Caution

# %%
raining = True
Muddy = True

if raining == True:
    print("Rain coat is necessary")
    if Muddy == True:
        print("Sandal is nesessary")
else:
    print("Go without rain coat")
    print("This is a sunny day")
# Out:
# Rain coat is necessary
# Sandal is nesessary

# %%
taka = 1000


if taka > 500 :
    print("Ghurte jabo")
elif taka > 400 :
    print("Bashai Order korbo")
elif taka > 300 :
    print("Food court e jabo")
else:
    print("Saving korbo")
# Out:
# Ghurte jabo

# %%
taka = 1000
raining = True


if (taka > 500) and raining==False:
    print("Ghurte jabo")
else:
    print("Saving korbo")
# Out:
# Saving korbo
